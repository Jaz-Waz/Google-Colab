# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 443
VIS2_MEAN = 395.5
VIS1_STD = 88.48
VIS2_STD = 93.19

# %% [markdown]
# # New Section

# %%
# build a bar plot
plt.bar(['Person 1 Visual 1', 'Person 1 Visual 2'],[VIS1_MEAN, VIS2_MEAN], yerr=[VIS1_STD, VIS2_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual 1 vs. Visual 2')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual 1 vs. Visual 2')
